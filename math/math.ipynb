# %% [markdown]
# # Calculus
# ## 1. 函数
#
# ## 2. 导数
#
# ### 2.1 极限
#
# ### 2.2 无穷大
#
# ### 2.3 连续性与导数
#
# 1. 连续性： 设函数y=f(x)在点X0的某邻域内有定义，如果当自变量的该变量$\Delta X$趋近于零时，相应函数的改变量$\Delta Y$也趋近于零，则称y=f(x)在点X0处连续。
# 2. 导数：如果平均变化率的极限存在， $\lim\limits_{\Delta X\rightarrow0}\frac{\Delta y}{\Delta x}= \lim\limits_{\Delta X\rightarrow0}\frac{f(x_0+\Delta x)-f(x_0)}{\Delta x}$,则称此极限为函数y=f(x)在点x0处的导数，$f^{'}(x_0)$
#
# #### 求导

# %% [markdown]
# ## 3. 偏导数
#
# 二元函数z=f(x,y)存在z随x变化的变化率，随y变化的变化率，随x,y同时变化的变化率。
# **偏导数定义**：设函数z=f(x,y)在点（x0,y0）的某个领域内有定义。令y=y0,一元函数f(x,y)在点x=x0处可导，即极限$\lim\limits_{\Delta x \rightarrow 0}\frac{f(x_{0}+\Delta x,y_{0})-f(x_{0},y_{0})}{\Delta x}=A$;则称A为函数：z=f(x,y)在点（x0,y0）处关于自变量X的偏导数
# ### 3.1 几何意义
# ![paritial derivative](.\figs\partial_derivative.JPG)
#
# ## 4. 方向导数
# ## 5. 梯度
#
# 梯度为等高线上的法向量，由低指向高

# %% [markdown]
# ## 6. 泰勒公式
# 1. 用简单的多项式来近似代替复杂的函数
# 2. 容易计算函数值，导数与积分仍是多项式
# 3. 多项式由它的系数完全确定，其系数又由它在的一点的函数值及其导数所确定
#
# ### 泰勒公式
# 若 $f^{'}(x_0)$存在，在x0附近有$f(x_0 +\Delta x)-f(x_0) \approx f^{'}x_0 \Delta x$
#
# 可以得到 $f(x) = f(x_0) + f^{'}(x_0)(x-x_0)+o(x-x_0)$
#
# 近似可得 $f(x) \approx {f(x_0)+f^{'}(x_0)(x-x_0)}$
#
# 1. 以直代曲
# ![](.\figs\fig1_talyor1.JPG)
# 2. 一点一世界
# ![](.\figs\fig2_talyor2.JPG)
#
# ### 泰勒多项式
# $P_n(x) = f(x_0)+f^{'}(x_0)(x-x_0)+\frac{f^{''}(x_0)}{2!}{(x-x_0)}^2+ \cdot \cdot \cdot + \frac{f^n(x_0)}{n!}{(x-x_0)}^n$
#
# 称为f(x)在x0关于（x-x0）的n阶泰勒多项式

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

x=np.linspace(0,8,100)
plt.plot(x,pow(math.e, x), label = "$y=e^x$")
plt.plot(x,1+x+pow(x,2)/2+pow(x,3)/math.factorial(3), label="3")
plt.plot(x,1+x+pow(x,2)/2+pow(x,3)/math.factorial(3)+pow(x,4)/math.factorial(4)+pow(x,5)/math.factorial(5)+pow(x,6)/math.factorial(6), label = "6")
plt.plot(x,1+x+pow(x,2)/2+pow(x,3)/math.factorial(3)+pow(x,4)/math.factorial(4)+pow(x,5)/math.factorial(5)+pow(x,6)/math.factorial(6)+
         pow(x,7)/math.factorial(7)+pow(x,8)/math.factorial(8)+pow(x,9)/math.factorial(9),label="9")
plt.legend()
plt.show()

# %% [markdown]
# ## 7. 拉格朗日乘子法

# %% [markdown]
# # Linear algebra
# ##
